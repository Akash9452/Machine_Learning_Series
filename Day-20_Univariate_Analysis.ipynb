# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **import dataset**

# %%
df = pd.read_csv('/content/iris_DATASET.json')
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Understaning the data**

# %% [markdown]
# **How big is data?**
#
# ---
#
#
# **How does the data looks like?**
#
# ---
#
#
# **How does the data type of columns?**
#
# ---
#
#
# **Are there any missing values?**
#
# ---
#
# **Are there any duplicate values?**
#
# ---
# **How does the data looks mathematically?**
#
#
# ---
#
#
#
# **How is the Correlation btw the columns?**
#
# ---

# %% [markdown]
# # How big is data?

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # How does the data looks like?

# %%
df.head(5)
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
df.sample(5)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth     species
# 43           5.0         3.5          1.6         0.6      setosa
# 2            4.7         3.2          1.3         0.2      setosa
# 63           6.1         2.9          4.7         1.4  versicolor
# 29           4.7         3.2          1.6         0.2      setosa
# 103          6.3         2.9          5.6         1.8   virginica

# %% [markdown]
# # How does the data type of columns?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepalLength  150 non-null    float64
#  1   sepalWidth   150 non-null    float64
#  2   petalLength  150 non-null    float64
#  3   petalWidth   150 non-null    float64
#  4   species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Are there any missing values?

# %%
df.isnull().sum()
# Out:
# sepalLength    0
# sepalWidth     0
# petalLength    0
# petalWidth     0
# species        0
# dtype: int64

# %% [markdown]
# # Are there any duplicate values?

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# # How does the data looks mathematically?

# %%
df.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# # How is the Correlation btw the columns?

# %%
df2=pd.read_csv('/content/iris_DATASET.json', usecols=['sepalLength',	'sepalWidth',	'petalLength',	'petalWidth'])

# %%
df2
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepalLength  150 non-null    float64
#  1   sepalWidth   150 non-null    float64
#  2   petalLength  150 non-null    float64
#  3   petalWidth   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df2.corr()
# Out:
#              sepalLength  sepalWidth  petalLength  petalWidth
# sepalLength     1.000000   -0.117570     0.871754    0.817941
# sepalWidth     -0.117570    1.000000    -0.428440   -0.366126
# petalLength     0.871754   -0.428440     1.000000    0.962865
# petalWidth      0.817941   -0.366126     0.962865    1.000000

# %% [markdown]
# # EDA

# %% [markdown]
# **Categorical data**
#
#
# 1.   use countplot in Seaborn
# 2.   use piechart in Seaborn

# %%
palette = ['red', 'green', 'blue']
sns.countplot(x='species',data=df, palette=palette)
# Out:
# <ipython-input-54-5c3b8e4be78c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species',data=df, palette=palette)
# <Axes: xlabel='species', ylabel='count'>

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df['species'].value_counts().plot(kind='bar', color=palette)
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# **Numerical_data**

# %% [markdown]
# 1.   Histogram

# %%
plt.hist(df['sepalLength'],bins=30)
# Out:
# (array([ 4.,  1.,  4.,  2.,  5., 16.,  9.,  4.,  1.,  6., 13.,  8.,  7.,
#          3.,  6., 10.,  9.,  7.,  5.,  2., 11.,  4.,  1.,  1.,  4.,  1.,
#          0.,  1.,  4.,  1.]),
#  array([4.3 , 4.42, 4.54, 4.66, 4.78, 4.9 , 5.02, 5.14, 5.26, 5.38, 5.5 ,
#         5.62, 5.74, 5.86, 5.98, 6.1 , 6.22, 6.34, 6.46, 6.58, 6.7 , 6.82,
#         6.94, 7.06, 7.18, 7.3 , 7.42, 7.54, 7.66, 7.78, 7.9 ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# 2. Distplot

# %%
sns.distplot(df['sepalLength'],bins = 30)
# Out:
# <ipython-input-62-ae6d9c0bfb19>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepalLength'],bins = 30)
# <Axes: xlabel='sepalLength', ylabel='Density'>

# %% [markdown]
# 3.   Boxplot

# %%
sns.boxplot(df['sepalLength'])
# Out:
# <Axes: ylabel='sepalLength'>
